# %%
import numpy as np

# %matplotlib notebook
import matplotlib.pyplot as plt
# import seaborn as sns
# sns.set()

import pymesh

# %%
mesh_fname = '../data/benchmark/db/0/m0/m0.off'

# %%
mesh = pymesh.load_mesh(mesh_fname)

# %%
plt.scatter(mesh.vertices)

# %%
mesh.vertices

# %%
import pyntcloud

# %%
test = pyntcloud.PyntCloud.from_file(mesh_fname)

# %%
test.points
# Out:
#             x         y         z
# 0    0.270598  0.254439  0.471311
# 1    0.270598  0.254439  0.518814
# 2    0.270598  0.282268  0.518814
# 3    0.270598  0.282268  0.471311
# 4    0.396951  0.254439  0.471311
# 5    0.396951  0.282268  0.471311
# 6    0.396951  0.282268  0.518814
# 7    0.396951  0.254439  0.518814
# 8    0.255225  0.289674  0.437310
# 9    0.412324  0.289674  0.437310
# 10   0.412324  0.289674  0.389806
# 11   0.255225  0.289674  0.389806
# 12   0.412324  0.261845  0.389806
# 13   0.255225  0.261845  0.389806
# 14   0.255225  0.261845  0.437310
# 15   0.412324  0.261845  0.437310
# 16   0.265661  0.235924  0.326817
# 17   0.265661  0.235924  0.374321
# 18   0.265661  0.263753  0.374321
# 19   0.265661  0.263753  0.326817
# 20   0.401888  0.235924  0.326817
# 21   0.401888  0.263753  0.326817
# 22   0.401888  0.263753  0.374321
# 23   0.401888  0.235924  0.374321
# 24   0.393435  0.205626  0.240338
# 25   0.369383  0.239814  0.269064
# ...

# %%
test.plot(backend='matplotlib', initial_point_size=90)
# Out:
# <img src="data:image/png;base64,..." width="1000">
